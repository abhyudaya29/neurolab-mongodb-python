# %%
from database_connect import mongo_operation as mongo

client_uri = "mongodb+srv://Abhyudaya:Abhyudaya@cluster0.lkjxcm4.mongodb.net/?retryWrites=true&w=majority"
database_name = "DEV"


def upload_files_to_mongodb(
    mongo_client_con_string,
    database_name,
    datasets_dir_name):
  
  for file in os.listdir(datasets_dir_name):
    if file.endswith('.csv'):
      file_name = file.split('.')[0]

      mongo_connection = mongo(
          client_url = mongo_client_con_string,
          database_name= database_name,
          collection_name= file_name
      )

      file_path = os.path.join(datasets_dir_name, file_name)
      mongo_connection.bulk_insert(file)
      print(f"{file_name} is uploaded to mongodb")


upload_files_to_mongodb(
    mongo_client_con_string= client_url,
    database_name = database_name,
    datasets_dir_name= "notebook/wafer.csv"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 27
#      23       mongo_connection.bulk_insert(file)
#      24       print(f"{file_name} is uploaded to mongodb")
# ---> 27 upload_files_to_mongodb(
#      28     mongo_client_con_string= client_url,
#      29     database_name = database_name,
#      30     datasets_dir_name= "notebook/wafer.csv"
#      31 )
#
# Cell In[44], line 12, in upload_files_to_mongodb(mongo_client_con_string, database_name, datasets_dir_name)
#       7 def upload_files_to_mongodb(
#       8     mongo_client_con_string,
#       9     database_name,
#      10     datasets_dir_name):
# ---> 12   for file in os.listdir(datasets_dir_name):
#      13     if file.endswith('.csv'):
#      14       file_name = file.split('.')[0]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'notebook/wafer.csv'

# %%
from pymongo.mongo_client import MongoClient


import pandas as pd
import json

# %%
uri = "mongodb+srv://abhy:abhy@cluster0.nvfhgmm.mongodb.net/?retryWrites=true&w=majority"

# %%
client = MongoClient(uri)

# %%
client
# Out:
# MongoClient(host=['ac-vg9s3ro-shard-00-00.cwmqbnt.mongodb.net:27017', 'ac-vg9s3ro-shard-00-01.cwmqbnt.mongodb.net:27017', 'ac-vg9s3ro-shard-00-02.cwmqbnt.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-bgd17o-shard-0', tls=True)

# %%
database_name="DEV"
connection_name="waferfault"

# %%
df=pd.read_csv(r"/config/workspace/notebook/wafer.csv")

# %%
df.drop("Unnamed: 0",axis=1)
# Out:
#     Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  Sensor-7  \
# 0    2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0   97.5822
# 1    2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0   96.7700
# 2    3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0  101.8644
# 3    3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0  101.8644
# 4    3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0  104.8856
# ..       ...       ...        ...        ...       ...       ...       ...
# 95   3013.66   2526.44  2185.2111  1141.6306    0.8447     100.0  100.5978
# 96   2982.87   2477.01  2315.2667  2360.1325    1.1259     100.0   90.1144
# 97   3084.82   2387.42  2171.5000  1028.4440    0.7899     100.0  101.5122
# 98   2955.87   2541.89        NaN        NaN       NaN       NaN       NaN
# 99   2914.86   2465.11  2210.2778  2120.5760    1.0700     100.0   95.1089
#
# ...

# %%
json_records=list(json.loads(df.T.to_json()).values())

# %%
client[database_name][connection_name].insert_many(json_records)

# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://abhy:abhy@cluster0.nvfhgmm.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
